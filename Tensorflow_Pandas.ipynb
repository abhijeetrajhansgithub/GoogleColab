# %% [markdown]
# <a href="https://colab.research.google.com/github/abhijeetrajhansgithub/GoogleColab/blob/main/Tensorflow_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.0.3

# %%
# 2 main datatypes

series = pd.Series(['BMW', 'Toyota', 'Honda'])

series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimentional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# Dataframe = 2-dimentional

car_data = pd.DataFrame({"Car Make": series, "Colour": colours})

car_data
# Out:
#   Car Make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import data

cars = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/exported-car-sales.csv")
cars
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
# exporting a dataframe

cars.to_csv("export-cars.csv", index = False)

# %%
exported_cars = pd.read_csv("export-cars.csv")

exported_cars
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ## Describe Data

# %%
# attribute
cars.dtypes
# Out:
# Unnamed: 0        int64
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
heart_disease.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
car_sales = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv")

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
prices = car_sales.iloc[:, 4]

prices
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
prices = [float(i[1:].replace(',', '')) for i in prices]

prices
# Out:
# [4000.0,
#  5000.0,
#  7000.0,
#  22000.0,
#  3500.0,
#  4500.0,
#  7500.0,
#  7000.0,
#  6250.0,
#  9700.0]

# %%
car_sales['Numeric Prices'] = prices

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices
# 0  Toyota  White         150043      4   $4,000.00          4000.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0
# 7   Honda   Blue          54738      4   $7,000.00          7000.0
# 8  Toyota  White          60000      4   $6,250.00          6250.0
# 9  Nissan  White          31600      4   $9,700.00          9700.0

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors  Numeric Prices
# count      10.000000  10.000000       10.000000
# mean    78601.400000   4.000000     7645.000000
# std     61983.471735   0.471405     5379.407753
# min     11179.000000   3.000000     3500.000000
# 25%     35836.250000   4.000000     4625.000000
# 50%     57369.000000   4.000000     6625.000000
# 75%     96384.500000   4.000000     7375.000000
# max    213095.000000   5.000000    22000.000000

# %%
car_sales.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Make            10 non-null     object
#  1   Colour          10 non-null     object
#  2   Odometer (KM)   10 non-null     int64
#  3   Doors           10 non-null     int64
#  4   Price           10 non-null     object
#  5   Numeric Prices  10 non-null     float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 608.0+ bytes

# %%
car_sales['Numeric Prices'].mean()
# Out:
# 7645.0

# %%
car_sales['Numeric Prices'].sum()
# Out:
# 76450.0

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices
# 0  Toyota  White         150043      4   $4,000.00          4000.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices
# 0  Toyota  White         150043      4   $4,000.00          4000.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Numeric Prices
# 5  Toyota  Green          99213      4  $4,500.00          4500.0
# 6   Honda   Blue          45698      4  $7,500.00          7500.0
# 7   Honda   Blue          54738      4  $7,000.00          7000.0
# 8  Toyota  White          60000      4  $6,250.00          6250.0
# 9  Nissan  White          31600      4  $9,700.00          9700.0

# %% [markdown]
# ## .loc and .iloc

# %%
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"],
                    index=[0, 3, 9, 8, 3])

animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                     BMW
# Colour                 Black
# Odometer (KM)          11179
# Doors                      5
# Price             $22,000.00
# Numeric Prices       22000.0
# Name: 3, dtype: object

# %%
animals.iloc[3]  # iloc refers to position
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                     BMW
# Colour                 Black
# Odometer (KM)          11179
# Doors                      5
# Price             $22,000.00
# Numeric Prices       22000.0
# Name: 3, dtype: object

# %%
animals.iloc[3:]
# Out:
# 8    panda
# 3    snake
# dtype: object

# %%
car_sales.loc[5:]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Numeric Prices
# 5  Toyota  Green          99213      4  $4,500.00          4500.0
# 6   Honda   Blue          45698      4  $7,500.00          7500.0
# 7   Honda   Blue          54738      4  $7,000.00          7000.0
# 8  Toyota  White          60000      4  $6,250.00          6250.0
# 9  Nissan  White          31600      4  $9,700.00          9700.0

# %%
car_sales.iloc[5:]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Numeric Prices
# 5  Toyota  Green          99213      4  $4,500.00          4500.0
# 6   Honda   Blue          45698      4  $7,500.00          7500.0
# 7   Honda   Blue          54738      4  $7,000.00          7000.0
# 8  Toyota  White          60000      4  $6,250.00          6250.0
# 9  Nissan  White          31600      4  $9,700.00          9700.0

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[ car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Numeric Prices
# 0  Toyota  White         150043      4  $4,000.00          4000.0
# 2  Toyota   Blue          32549      3  $7,000.00          7000.0
# 5  Toyota  Green          99213      4  $4,500.00          4500.0
# 8  Toyota  White          60000      4  $6,250.00          6250.0

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# GroupBy


car_sales.groupby(["Make"]).sum()
# Out:
#                      Colour  Odometer (KM)  Doors  \
# Make
# BMW                   Black          11179      5
# Honda           RedBlueBlue         188335     12
# Nissan           WhiteWhite         244695      8
# Toyota  WhiteBlueGreenWhite         341805     15
#
#                                        Price  Numeric Prices
# Make
# BMW                               $22,000.00         22000.0
# Honda            $5,000.00$7,500.00$7,000.00         19500.0
# Nissan                    $3,500.00$9,700.00         13200.0
# Toyota  $4,000.00$7,000.00$4,500.00$6,250.00         21750.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data with Pandas

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales_missing = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-missing-data.csv")

car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-missing-data.csv")

car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_mising_dropped = car_sales_missing.dropna()

car_sales_mising_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_mising_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# Column from Series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column named Seats
car_sales["Seats"] = seats_column

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats
# 0  Toyota  White         150043      4   $4,000.00          4000.0    5.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0    5.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0    5.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0    5.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0    5.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0    NaN
# 6   Honda   Blue          45698      4   $7,500.00          7500.0    NaN
# 7   Honda   Blue          54738      4   $7,000.00          7000.0    NaN
# 8  Toyota  White          60000      4   $6,250.00          6250.0    NaN
# 9  Nissan  White          31600      4   $9,700.00          9700.0    NaN

# %%
car_sales["Seats"].fillna(5 , inplace=True)

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats
# 0  Toyota  White         150043      4   $4,000.00          4000.0    5.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0    5.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0    5.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0    5.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0    5.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0    5.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0    5.0
# 7   Honda   Blue          54738      4   $7,000.00          7000.0    5.0
# 8  Toyota  White          60000      4   $6,250.00          6250.0    5.0
# 9  Nissan  White          31600      4   $9,700.00          9700.0    5.0

# %%
# Column from Python List

fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 4.0, 4.5]

car_sales["Fuel per 100KM"] = fuel_economy

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats  \
# 0  Toyota  White         150043      4   $4,000.00          4000.0    5.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0    5.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0    5.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0    5.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0    5.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0    5.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0    5.0
# 7   Honda   Blue          54738      4   $7,000.00          7000.0    5.0
# 8  Toyota  White          60000      4   $6,250.00          6250.0    5.0
# 9  Nissan  White          31600      4   $9,700.00          9700.0    5.0
#
#    Fuel per 100KM
# 0             7.5
# 1             9.2
# 2             5.0
# 3             9.6
# 4             8.7
# 5             4.7
# ...

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats  \
# 0  Toyota  White         150043      4   $4,000.00          4000.0    5.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0    5.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0    5.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0    5.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0    5.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0    5.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0    5.0
# 7   Honda   Blue          54738      4   $7,000.00          7000.0    5.0
# 8  Toyota  White          60000      4   $6,250.00          6250.0    5.0
# 9  Nissan  White          31600      4   $9,700.00          9700.0    5.0
#
#    Fuel per 100KM  Total fuel used
# 0             7.5        11253.225
# 1             9.2         8086.708
# 2             5.0         1627.450
# ...

# %%
# Create a column from a single value

car_sales["Number of wheels"] = 4

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats  \
# 0  Toyota  White         150043      4   $4,000.00          4000.0    5.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0    5.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0    5.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0    5.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0    5.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0    5.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0    5.0
# 7   Honda   Blue          54738      4   $7,000.00          7000.0    5.0
# 8  Toyota  White          60000      4   $6,250.00          6250.0    5.0
# 9  Nissan  White          31600      4   $9,700.00          9700.0    5.0
#
#    Fuel per 100KM  Total fuel used  Number of wheels
# 0             7.5        11253.225                 4
# ...

# %%
car_sales["Passed Road Safety"] = True
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                  object
# Numeric Prices        float64
# Seats                 float64
# Fuel per 100KM        float64
# Total fuel used       float64
# Number of wheels        int64
# Passed Road Safety       bool
# dtype: object

# %%
car_sales.drop("Total fuel used", axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats  \
# 0  Toyota  White         150043      4   $4,000.00          4000.0    5.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0    5.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0    5.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0    5.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0    5.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0    5.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0    5.0
# 7   Honda   Blue          54738      4   $7,000.00          7000.0    5.0
# 8  Toyota  White          60000      4   $6,250.00          6250.0    5.0
# 9  Nissan  White          31600      4   $9,700.00          9700.0    5.0
#
#    Fuel per 100KM  Number of wheels  Passed Road Safety
# 0             7.5                 4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats  \
# 1   Honda    Red          87899      4   $5,000.00          5000.0    5.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0    5.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0    5.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0    5.0
# 0  Toyota  White         150043      4   $4,000.00          4000.0    5.0
# 8  Toyota  White          60000      4   $6,250.00          6250.0    5.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0    5.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0    5.0
# 9  Nissan  White          31600      4   $9,700.00          9700.0    5.0
# 7   Honda   Blue          54738      4   $7,000.00          7000.0    5.0
#
#    Fuel per 100KM  Number of wheels  Passed Road Safety
# 1             9.2                 4                True
# ...

# %%
car_sales_shuffled.sample(frac=0.1)
# Out:
#   Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats  \
# 3  BMW  Black          11179      5  $22,000.00         22000.0    5.0
#
#    Fuel per 100KM  Number of wheels  Passed Road Safety
# 3             9.6                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats  \
# 0   Honda    Red          87899      4   $5,000.00          5000.0    5.0
# 1     BMW  Black          11179      5  $22,000.00         22000.0    5.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0    5.0
# 3  Nissan  White         213095      4   $3,500.00          3500.0    5.0
# 4  Toyota  White         150043      4   $4,000.00          4000.0    5.0
# 5  Toyota  White          60000      4   $6,250.00          6250.0    5.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0    5.0
# 7  Toyota  Green          99213      4   $4,500.00          4500.0    5.0
# 8  Nissan  White          31600      4   $9,700.00          9700.0    5.0
# 9   Honda   Blue          54738      4   $7,000.00          7000.0    5.0
#
#    Fuel per 100KM  Number of wheels  Passed Road Safety
# 0             9.2                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats  \
# 0  Toyota  White         150043      4   $4,000.00          4000.0    5.0
# 1   Honda    Red          87899      4   $5,000.00          5000.0    5.0
# 2  Toyota   Blue          32549      3   $7,000.00          7000.0    5.0
# 3     BMW  Black          11179      5  $22,000.00         22000.0    5.0
# 4  Nissan  White         213095      4   $3,500.00          3500.0    5.0
# 5  Toyota  Green          99213      4   $4,500.00          4500.0    5.0
# 6   Honda   Blue          45698      4   $7,500.00          7500.0    5.0
# 7   Honda   Blue          54738      4   $7,000.00          7000.0    5.0
# 8  Toyota  White          60000      4   $6,250.00          6250.0    5.0
# 9  Nissan  White          31600      4   $9,700.00          9700.0    5.0
#
#    Fuel per 100KM  Number of wheels  Passed Road Safety
# 0             7.5                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Numeric Prices  Seats  \
# 0  Toyota  White      93776.875      4   $4,000.00          4000.0    5.0
# 1   Honda    Red      54936.875      4   $5,000.00          5000.0    5.0
# 2  Toyota   Blue      20343.125      3   $7,000.00          7000.0    5.0
# 3     BMW  Black       6986.875      5  $22,000.00         22000.0    5.0
# 4  Nissan  White     133184.375      4   $3,500.00          3500.0    5.0
# 5  Toyota  Green      62008.125      4   $4,500.00          4500.0    5.0
# 6   Honda   Blue      28561.250      4   $7,500.00          7500.0    5.0
# 7   Honda   Blue      34211.250      4   $7,000.00          7000.0    5.0
# 8  Toyota  White      37500.000      4   $6,250.00          6250.0    5.0
# 9  Nissan  White      19750.000      4   $9,700.00          9700.0    5.0
#
#    Fuel per 100KM  Number of wheels  Passed Road Safety
# 0             7.5                 4                True
# ...
